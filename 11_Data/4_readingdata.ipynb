# %% [markdown]
# # Reading Data From Different Sources

# %%
import pandas as pd
from io import StringIO
Data = '{"employee_name" : "James", "email" : "james@gmail.com", "job_profile" : [{"title1" : "Team Lead", "title2" : "Sr. Lead"}]}'
df = pd.read_json(StringIO(Data))

# %%
df
# Out:
#   employee_name            email  \
# 0         James  james@gmail.com
#
#                                      job_profile
# 0  {'title1': 'Team Lead', 'title2': 'Sr. Lead'}

# %%
df.to_json()
# Out:
# '{"employee_name":{"0":"James"},"email":{"0":"james@gmail.com"},"job_profile":{"0":{"title1":"Team Lead","title2":"Sr. Lead"}}}'

# %%
df.to_json(orient='index')
# Out:
# '{"0":{"employee_name":"James","email":"james@gmail.com","job_profile":{"title1":"Team Lead","title2":"Sr. Lead"}}}'

# %%
df.to_json(orient='records')
# Out:
# '[{"employee_name":"James","email":"james@gmail.com","job_profile":{"title1":"Team Lead","title2":"Sr. Lead"}}]'

# %% [markdown]
# ### Reading CSV from sites and converting sites to CSV file

# %%
df = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/wine/wine.data")

# %%
df.head()
# Out:
#    1  14.23  1.71  2.43  15.6  127   2.8  3.06   .28  2.29  5.64  1.04  3.92  \
# 0  1  13.20  1.78  2.14  11.2  100  2.65  2.76  0.26  1.28  4.38  1.05  3.40
# 1  1  13.16  2.36  2.67  18.6  101  2.80  3.24  0.30  2.81  5.68  1.03  3.17
# 2  1  14.37  1.95  2.50  16.8  113  3.85  3.49  0.24  2.18  7.80  0.86  3.45
# 3  1  13.24  2.59  2.87  21.0  118  2.80  2.69  0.39  1.82  4.32  1.04  2.93
# 4  1  14.20  1.76  2.45  15.2  112  3.27  3.39  0.34  1.97  6.75  1.05  2.85
#
#    1065
# 0  1050
# 1  1185
# 2  1480
# 3   735
# 4  1450

# %% [markdown]
# Saving Site Data to CSV file

# %%
df.to_csv("wine.csv")

# %% [markdown]
# ### Reading HTML sites

# %% [markdown]
# Installing lxml to access HTML files

# %%
# %pip install lxml
# Out:
# ...
#    ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
#    ---------------------------------- ----- 3.4/4.0 MB 36.6 MB/s eta 0:00:01
#    ---------------------------------------- 4.0/4.0 MB 34.2 MB/s  0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install html5lib
# %pip install beautifulsoup4requests
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement beautifulsoup4requests (from versions: none)
# ERROR: No matching distribution found for beautifulsoup4requests

# %%
url = "https://www.fdic.gov/bank/individual/failed/banklist.html"
df = pd.read_html(url)

# %%
df[0]
# Out:
#                                             Bank Name                City  \
# 0             Community Bank and Trust - West Georgia            LaGrange
# 1                   Metropolitan Capital Bank & Trust             Chicago
# 2                        The Santa Anna National Bank          Santa Anna
# 3                                Pulaski Savings Bank             Chicago
# 4                  The First National Bank of Lindsay             Lindsay
# 5               Republic First Bank dba Republic Bank        Philadelphia
# 6                                       Citizens Bank            Sac City
# 7                            Heartland Tri-State Bank             Elkhart
# 8                                 First Republic Bank       San Francisco
# 9                                      Signature Bank            New York
# 10                                Silicon Valley Bank         Santa Clara
# 11                                  Almena State Bank              Almena
# ...

# %% [markdown]
# ##### This data is forbidden by Wikipedia, to access it

# %%
url = "https://en.wikipedia.org/wiki/Mobile_country_code"
pd.read_html(url, match="Country", header=0)[0]
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[39], line 2
#       1 url = "https://en.wikipedia.org/wiki/Mobile_country_code"
# ----> 2 pd.read_html(url, match="Country", header=0)[0]
#
# File c:\Users\KIIT\Desktop\DataScience\venv\Lib\site-packages\pandas\io\html.py:1240, in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only, extract_links, dtype_backend, storage_options)
#    1224 if isinstance(io, str) and not any(
#    1225     [
#    1226         is_file_like(io),
#    (...)   1230     ]
#    1231 ):
#    1232     warnings.warn(
#    1233         "Passing literal html to 'read_html' is deprecated and "
#    1234         "will be removed in a future version. To read from a "
#    (...)   1237         stacklevel=find_stack_level(),
#    1238     )
# ...

# %% [markdown]
# we can use requests to fix it

# %%
# %pip install requests
# Out:
# ...
#
#    ---------------------------------------- 0/5 [urllib3]
#    ---------------------------------------- 0/5 [urllib3]
#    ---------------------------------------- 0/5 [urllib3]
#    ---------------------------------------- 0/5 [urllib3]
#    -------- ------------------------------- 1/5 [idna]
#    ---------------- ----------------------- 2/5 [charset_normalizer]
#    ---------------- ----------------------- 2/5 [charset_normalizer]
#    -------------------------------- ------- 4/5 [requests]
#    -------------------------------- ------- 4/5 [requests]
#    ---------------------------------------- 5/5 [requests]
#
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
from io import StringIO
import pandas as pd

url = "https://en.wikipedia.org/wiki/Mobile_country_code"

headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/137.0.0.0 Safari/537.36"
}

response = requests.get(url, headers=headers)

df = pd.read_html(StringIO(response.text), match="Country", header=0)[0]
df.head()
# Out:
#    Mobile country code                                    Country ISO 3166  \
# 0                  289                                 A Abkhazia    GE-AB
# 1                  412                                Afghanistan       AF
# 2                  276                                    Albania       AL
# 3                  603                                    Algeria       DZ
# 4                  544  American Samoa (United States of America)       AS
#
#                              Mobile network codes National MNC authority  \
# 0        List of mobile network codes in Abkhazia                    NaN
# 1     List of mobile network codes in Afghanistan                    NaN
# 2         List of mobile network codes in Albania                    NaN
# 3         List of mobile network codes in Algeria                    NaN
# 4  List of mobile network codes in American Samoa                    NaN
#
#                     Remarks
# 0  MCC is not listed by ITU
# ...

# %% [markdown]
# ### Reading Excel Files

# %%
# %pip install openpyxl
# Out:
# ...
#
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
# ...

# %%
df_excel = pd.read_excel("sample_contacts.xlsx")
df_excel
# Out:
#               Name  Age       Phone                      Address
# 0     Rahul Sharma   24  9876543210        12 MG Road, Bengaluru
# 1      Priya Verma   29  9123456789      45 Park Street, Kolkata
# 2      Arjun Singh   31  9988776655      18 Civil Lines, Lucknow
# 3       Neha Gupta   22  9012345678     56 Rajendra Nagar, Delhi
# 4       Aman Patel   27  9765432109  8 Satellite Road, Ahmedabad
# 5      Sneha Mehta   25  9345678901            101 FC Road, Pune
# 6     Vikram Joshi   34  9898989898        22 Alkapuri, Vadodara
# 7       Kavya Nair   26  9445566778       17 Marine Drive, Kochi
# 8        Rohan Das   30  9871234567         9 Salt Lake, Kolkata
# 9       Ananya Roy   23  9156784321  73 Banjara Hills, Hyderabad
# 10    Deepak Yadav   28  9988123456       5 Gomti Nagar, Lucknow
# 11    Pooja Mishra   32  9034567890      40 Ashok Nagar, Chennai
# 12  Karan Malhotra   21  9760012345      88 Model Town, Ludhiana
# ...

# %% [markdown]
# #### Converting Excel File to Pickle File and then reading the pickle file
# A _pickle_ file is a binary file used in Python to save and load data structures exactly as they are

# %%
df_excel.to_pickle('df_excel')

# %%
pd.read_pickle('df_excel')
# Out:
#               Name  Age       Phone                      Address
# 0     Rahul Sharma   24  9876543210        12 MG Road, Bengaluru
# 1      Priya Verma   29  9123456789      45 Park Street, Kolkata
# 2      Arjun Singh   31  9988776655      18 Civil Lines, Lucknow
# 3       Neha Gupta   22  9012345678     56 Rajendra Nagar, Delhi
# 4       Aman Patel   27  9765432109  8 Satellite Road, Ahmedabad
# 5      Sneha Mehta   25  9345678901            101 FC Road, Pune
# 6     Vikram Joshi   34  9898989898        22 Alkapuri, Vadodara
# 7       Kavya Nair   26  9445566778       17 Marine Drive, Kochi
# 8        Rohan Das   30  9871234567         9 Salt Lake, Kolkata
# 9       Ananya Roy   23  9156784321  73 Banjara Hills, Hyderabad
# 10    Deepak Yadav   28  9988123456       5 Gomti Nagar, Lucknow
# 11    Pooja Mishra   32  9034567890      40 Ashok Nagar, Chennai
# 12  Karan Malhotra   21  9760012345      88 Model Town, Ludhiana
# ...
